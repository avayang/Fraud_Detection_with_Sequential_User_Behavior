# %%
#!pip install -q tf-nightly

# %%
import tensorflow as tf
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import os 
import pickle
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# os.chdir("drive/My Drive/Code _ Data/6.new_data") 
os.chdir("drive/My Drive/Online Lending/Sequential Embedding/Spring 2020/Final Submission/Data/low_income_data/processed") # give the path to the data file.
os.listdir()
# Out:
# Mounted at /content/drive
# ['padded_sequential_features_embedded.json',
#  'padded_sequential_features_3.json',
#  'non_sequential_features_2.json',
#  'featurematrix.json',
#  'embedding_sequence.p',
#  'stay_time_sequence.p',
#  'label.json',
#  'checkpoints']

# %% [markdown]
# # Setup Input

# %%
with open('label.json') as f:
    labels = json.load(f)
with open('embedding_sequence.p', 'rb') as f:
    embedding_sequence = pickle.load(f)
with open('stay_time_sequence.p', 'rb') as f:
    stay_time_sequence = pickle.load(f)
label = np.array([[labels[key]] for key in labels.keys()], dtype=np.float32)
embedding_sequence = np.array(embedding_sequence, dtype=np.float32)
stay_time_sequence = np.array(stay_time_sequence, dtype=np.float32)
stay_time_sequence = stay_time_sequence.reshape(-1, 60, 1)
labels.keys()
# Out:
# dict_keys(['0ed9672fa61f4d6da241a6289000e2f2|1507102200000', '48b72ca5b43248d3b50dfadb76c651a2|1508810700000', '8e669f481a4645c89de0f29f980522e9|1508354520000', 'd9a86017a67140ab96d9c405d1ebb02d|1507129920000', '96e3ded73e6b47ba91108e5b6a923c81|1509348180000', '593c8f76b5164c08a52c7fc1bf99d283|1508970600000', 'e87ffe735fba4541a009967d25b0e714|1507058160000', '8e6c5ba3d14c41539b64816c4692f142|1507671840000', '3f8e1ae4c91147138fbdc5ea8aa17302|1508903820000', 'ed76629b471b4496ab9b979eda237c20|1508883240000', '29599c82724245d0bc4cd1c9aa46bd30|1507700940000', '44d6274bca6042d09b25df7381794e22|1508774400000', '8d475b039ea443cf829845b9a734faa2|1507670940000', '1735f9857aae47d3ade1ba0a76a18b6e|1508730540000', '166f5c79849d4b9488e7685fbac0a1f1|1508452140000', '8c459717bc174feaae85b29d5e1bd168|1508544120000', '8595f66de9864304ac09d0f66e77dfda|1509043980000', '24821c4b70d7463ca92ff38e24cc3b68|1508793900000', '5faff42341e9486ba18e7bc2baaa10b3|1508782200000', '33f054557aff4e17b51c46ed5840eca1|1509217200000', '2efa66222f6c494690390d5d238381cd|1507762620000', '322dab70424a40d5b7af5a6a350548c8|1507504440000', '79396118ad044e3faba1a64ba2de1dcc|1509207240000', '6bf0117752924c8dbdbeb583e6a9bf79|1508451120000', '7f17f41e90f24beab7b750f0dc308760|1508304660000', 'b41c4c9a4e4947e9b5859149dfa9ceb4|1506793080000', '09f57898f1674ed7b9c62ce8d4156848|1508986320000', '024da7352934426183b2f8914efd6b3b|1508525760000', 'cb3dcdf4bf224d98ad55b723d4b7d758|1509126960000', 'd0f2f1e8380c4a36aed2fbbbb63950c0|1508537220000', 'cfa2888c5edd4d66867ff8cec0522275|1509046140000', 'afaf945ac62041d29b681376a323f9d8|1509229380000', 'c791f83b77e54a4ebdb5c47045f93274|1508635260000', 'ab7754c0ee7a4c2aa00ca6475af68a02|1508547600000', '88e1fde16a8f4cc68b79da20feb8c46e|1507496520000', '839e608720b443bd988cd9d6c7a1985b|1509148140000', 'b884047b800246b38de0f4506b32d84f|1509205560000', 'c7c1ba0da1ab4a8faf5ab460bd78126b|1508636280000', '60bc94488d1f4e578fdc9910009bc539|1508369220000', 'df24763eaa514328accb49601dce7f74|1507761300000', 'a8faf5f0ff75486f9e06690d4e65b808|1507671420000', '33a2335dce874b89a2aa0c36d20a0e96|1509359340000', '8f1c4d782ddf49abbd496568a4e0f16d|1508878680000', 'b8c9cbcaa75144dca895cf5e02fa304f|1508179020000', 'fd3d917a3d3a4f528403e620e030575d|1507540740000', 'b33673d59ffb42e98de01e41d8a4c809|1508742240000', 'ad5a3100fd414d529e83ef02db56da43|1508718000000', 'bb1a8c5a83bd4b1b8bee1fc0fb2ac686|1509166200000', 'e8afeaa6c4364a6786fdeb86e4661aba|1509347220000', 'b4ace9878fde4580a8e9e9e6e936a5cd|1509047280000', '1aaf56a21a164a63934e995c23eeaaa0|1508771100000', '50936292ea514c8d9a0880ba81871fb7|1508510760000', '785c87ad7f2c4cecb166e79083401340|1507257660000', '9cec2891350b40dab04af078abb4633f|1508626560000', 'e1bdcd8e54564b5a81f4be53d406c43d|1509231480000', '4c65b43d4e954a96af2957ad957d170c|1508182320000', 'fadbecb16aa94ca2ab6866b9d4b08806|1509143040000', '1347fa4598674c24b2fbdc18a5637631|1507222140000', '2439a454a28242d785f62b597d41d28f|1508289720000', '880b5f60b51e447ab82c3143944cb41b|1509410640000', '53d9574d1529415ebe9c8747a5caec64|1507348320000', 'df31e14c707f4b25b00f1dc10ef7ec3e|1507084080000', 'c76f4f1b01fa43efbf86d0efdb37067a|1508017980000', 'cfc395778baf461b93cd342b331f6495|1509077280000', '19cf15d4674e483c869a839cd9214ec5|1507916520000', 'cdfd7bc2695243939953c3f77d225aa2|1508828820000', '2288b42e54f544a89833b2bbba0661dc|1508430540000', 'd5428533ec754decbf6e0a0a180c7abf|1508543280000', '6ee24f5d14924033894655e7ba2397d8|1508775360000', '9706bac38708415b8e48d04b72f8c7c4|1508950740000', '6820d085a5414a78a4bb8e2520ec199d|1508719200000', 'f84fe4b4ea254811b25173d6a752c26b|1509139320000', 'a1a68616713947c6acd3df8ea7c87788|1507737600000', '07bdae51190f4890b43ff912e6601004|1507679340000', 'dcca7c6dc1db4ac785aed9990c538ee5|1506825360000', 'fe29c642bb7f4827b6c7a6e6a79defa4|1508612220000', 'd1157f4cb70b48a8a192c6ef697c3cbc|1508996880000', '6a4c3ba4208645ccb19e7a7443675f8d|1507319580000', 'f751eeb6e2614dd09658ccb7a7a8e602|1508453640000', '794a65c99b284dd6b69eceb539f68065|15089 ...

# %%
stay_time_sequence.shape
# Out:
# (19617, 60, 1)

# %%
embedding_sequence.shape
# Out:
# (19617, 60, 50)

# %%
label.shape
# Out:
# (19617, 1)

# %% [markdown]
# # Train Test Split

# %%
train_behavior, test_behavior, train_stay_time, test_stay_time, train_label, test_label = train_test_split(
    embedding_sequence, stay_time_sequence, label, test_size=0.1)
train_behavior.shape, train_stay_time.shape, train_label.shape
# Out:
# ((17655, 60, 50), (17655, 60, 1), (17655, 1))

# %% [markdown]
# # Set Hyperparameters

# %%
#num_layers = 4
#d_model = 128
#dff = 512
#num_heads = 8

#input_size = 149923
#target_size = 149923
# dropout_rate = 0.1
batch_size = 64
learning_rate = 0.01

# %% [markdown]
# # Positional Encoding

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
pos_encoding = positional_encoding(50, 512)
print (pos_encoding.shape)
# Out:
# (1, 50, 512)

# %% [markdown]
# # Multi-head Attention Layer

# %%
#In this architecture, we choose to construct without mask 
def scaled_dot_product_attention(q, k, v):
  """
  Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead) 
  but it must be broadcastable for addition.
  
  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable 
          to (..., seq_len_q, seq_len_k). Defaults to None.
    
  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  
  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  #if mask is not None:
  #  scaled_attention_logits += (mask * -1e9)  

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model
    
    assert d_model % self.num_heads == 0
    
    self.depth = d_model // self.num_heads
    
    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)
    
    self.dense = tf.keras.layers.Dense(d_model)
        
  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])
    
  def call(self, v, k, q):
    batch_size = tf.shape(q)[0]
    
    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)
    
    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
    
    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v)
    
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention, 
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
    return output, attention_weights

# %% [markdown]
# # Feed-forward Network

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation="relu"),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %% [markdown]
# # Encoder Layer

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    
  def call(self, x, training):

    attn_output, _ = self.mha(x, x, x)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
    
    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(x + ffn_output)  # (batch_size, input_seq_len, d_model)
    
    return out2

# %%
sample_encoder_layer = EncoderLayer(512, 8, 2048)

sample_encoder_layer_output = sample_encoder_layer(
    tf.random.uniform((64, 60, 512)), False)

sample_encoder_layer_output.shape  # (batch_size, input_seq_len, d_model)
# Out:
# TensorShape([64, 60, 512])

# %% [markdown]
# # Decoder Layer

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    # self.ffn1 = point_wise_feed_forward_network(d_model, dff)
    self.ffn2 = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
  def call(self, x, enc_output, training):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    # ffn_output1 = self.ffn1(x)  # (batch_size, input_seq_len, d_model)
    # ffn_output1 = self.dropout1(ffn_output1, training=training)
    # out1 = self.layernorm1(x + ffn_output1)  # (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)
    
    attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
    
    ffn_output2 = self.ffn2(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output2 = self.dropout3(ffn_output2, training=training)
    out3 = self.layernorm3(ffn_output2 + out2)  # (batch_size, target_seq_len, d_model)
    
    return out3, attn_weights_block2

# %%
sample_decoder_layer = DecoderLayer(512, 8, 2048)

sample_decoder_layer_output, _ = sample_decoder_layer(tf.random.uniform((64, 50, 512)), sample_encoder_layer_output, False)

sample_decoder_layer_output.shape  # (batch_size, target_seq_len, d_model)
# Out:
# TensorShape([64, 50, 512])

# %% [markdown]
# # Encoder

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    # self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, self.d_model)
    
    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
  
    self.dropout = tf.keras.layers.Dropout(rate)
        
  def call(self, x, training):

    seq_len = tf.shape(x)[1]
    
    # adding embedding and position encoding.
    # x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)
    
    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training)
    
    return x  # (batch_size, input_seq_len, d_model)

# %%
sample_encoder = Encoder(num_layers=2, d_model=50, num_heads=10, dff=2048, maximum_position_encoding=60)
temp_input = tf.random.uniform((64, 60, 50), dtype=tf.float32, minval=0, maxval=200)

sample_encoder_output = sample_encoder(temp_input, training=False)

print (sample_encoder_output.shape)  # (batch_size, input_seq_len, d_model)
# Out:
# (64, 60, 50)

# %% [markdown]
# # Decoder

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    #self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)
    
    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
    
    self.dropout = tf.keras.layers.Dropout(rate)
    
  def call(self, x, enc_output, training):

    seq_len = tf.shape(x)[1]
    attention_weights = {}
    
    #x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
    
    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block2 = self.dec_layers[i](x, enc_output, training)
      
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
sample_decoder = Decoder(num_layers=2, d_model=50, num_heads=5, dff=2048, maximum_position_encoding=60)
temp_input = tf.random.uniform((64, 26, 50), dtype=tf.float32, minval=0, maxval=200)

output, attn = sample_decoder(temp_input,enc_output=sample_encoder_output,training=False)

output.shape, attn['decoder_layer2_block2'].shape
# Out:
# (TensorShape([64, 26, 50]), TensorShape([64, 5, 26, 60]))

# %% [markdown]
# # Transformer

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, target_size, maximum_position_encoding, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff, maximum_position_encoding, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff, maximum_position_encoding, rate)

    self.final_layer1 = tf.keras.layers.Dense(target_size)
    self.final_layer3 = tf.keras.layers.Dense(1, activation = "sigmoid")
    
  def call(self, inp, tar, training, batch_size):

    enc_output = self.encoder(inp, training)  # (batch_size, inp_seq_len, d_model)
    
    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(tar, enc_output, training)
    
    final_output1 = self.final_layer1(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
    final_output2 = tf.reshape(final_output1, (batch_size, -1))
    final_output3 = self.final_layer3(final_output2)
    return final_output3, attention_weights
sample_transformer = Transformer(num_layers=2, d_model=50, num_heads=10, dff=512, target_size=60, maximum_position_encoding=60)

# %%
tf.executing_eagerly()
# Out:
# True

# %%
sample_transformer = Transformer(num_layers=2, d_model=50, num_heads=10, dff=512, target_size=60, maximum_position_encoding=60)

#temp_input = tf.random.uniform((100,60,50), dtype=tf.float32, minval=0, maxval=200)
#temp_target = tf.random.uniform((100,60,1), dtype=tf.float32, minval=0, maxval=200)
fn_out, _ = sample_transformer(embedding_sequence[:32], stay_time_sequence[:32], training=False, batch_size=32)

# fn_out, _ = sample_transformer(temp_input, temp_target, training=False)

fn_out  # (batch_size, tar_seq_len, target_vocab_size)
# Out:
# <tf.Tensor: shape=(32, 1), dtype=float32, numpy=
# array([[0.68252665],
#        [0.61879677],
#        [0.61437434],
#        [0.69795674],
#        [0.62871796],
#        [0.51787955],
#        [0.6743629 ],
#        [0.45355383],
#        [0.4457503 ],
#        [0.55697167],
#        [0.7634629 ],
#        [0.3396472 ],
#        [0.52341056],
#        [0.3399135 ],
#        [0.6704887 ],
#        [0.504996  ],
#        [0.57200223],
#        [0.44198722],
#        [0.412749  ],
#        [0.4065414 ],
#        [0.6647164 ],
#        [0.48107955],
#        [0.39649278],
#        [0.63154227],
#        [0.3698364 ],
#        [0.6551363 ],
#        [0.3772271 ],
#        [0.40569723],
#        [0.53668433],
#        [0.35557604],
#        [0.635695  ],
#        [0.56372315]], dtype=float32)>

# %% [markdown]
# # Optimizer

# %%
learning_rate = 0.1
optimizer = tf.keras.optimizers.Adam(learning_rate, epsilon=1e-9)

# %%
# d_model=50

# %% [markdown]
# # loss

# %%
def loss_function(y_true, y_pred):
  # dot_product = y*tf.log(output)
  # xentropy = -tf.reduce_sum(dot_product, reduction_indices=1)
  # loss = tf.reduce_mean(xentropy)
#   bce = tf.keras.losses.BinaryCrossentropy()
#   loss = bce(y_true, y_pred)

  sfce = tfa.losses.SigmoidFocalCrossEntropy()
  loss = sfce(y_true, y_pred)

  return loss

# %% [markdown]
# # Evaluation

# %%
# def evaluate(output, y):
#     """
#     evaluates the accuracy on the validation set 
#     input:
#         -output: prediction vector of the network for the validation set
#         -y: true value for the validation set
#     output:
#         - accuracy: accuracy on the validation set (scalar between 0 and 1)
#     """
#     #correct prediction is a binary vector which equals one when the output and y match
#     #otherwise the vector equals 0
#     #tf.cast: change the type of a tensor into another one2
#     #then, by taking the mean of the tensor, we directly have the average score, so the accuracy
    
#     correct_prediction = tf.equal(tf.argmax(output, 1), tf.argmax(y, 1))
#     accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
#     tf.summary.scalar("validation_error", (1.0 - accuracy))
#     return accuracy

# %% [markdown]
# # Main Function

# %%
def data_generator(x1, x2, y, batch_size=32):
  while True:
    total_batch = len(y)//batch_size
    # if total_batch < len(y)/batch_size:
    #   total_batch += 1
    batch_ind = 0
    while batch_ind < total_batch:
      start = batch_ind * batch_size
      end = (batch_ind + 1) * batch_size
      batch_ind += 1
      yield x1[start:end], x2[start:end], y[start:end]
# g = data_generator(x1,x2,y)
# next(g)

# %%
x1 = train_behavior[:]
x2 = train_stay_time[:]
y = train_label[:]

# %%
checkpoint_path = "checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=sample_transformer,optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
# if ckpt_manager.latest_checkpoint:
#   ckpt.restore(ckpt_manager.latest_checkpoint)
#   print ('Latest checkpoint restored!!')

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.

train_step_signature = [
    tf.TensorSpec(shape=(batch_size, 60, 50), dtype=tf.float32),
    tf.TensorSpec(shape=(batch_size, 60, 1), dtype=tf.float32),
    tf.TensorSpec(shape=(batch_size, 1), dtype=tf.float32)
]

@tf.function(input_signature=train_step_signature)
def train_step(inp1, inp2, tar):
  
  with tf.GradientTape() as tape:
    predictions, _ = sample_transformer(inp1, inp2, True, batch_size)
    loss = loss_function(tar, predictions)

  gradients = tape.gradient(loss, sample_transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, sample_transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(tar, predictions)
  train_AUC(tar, predictions)
  # print(predictions[:10])

# %%
EPOCHS = 8
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.BinaryAccuracy(name='train_accuracy')
train_AUC = tf.keras.metrics.AUC(name='train_AUC')
# optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)
optimizer = tf.keras.optimizers.Adam()
for epoch in range(EPOCHS):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  train_AUC.reset_states()
  total_batch = int(len(x1)/batch_size)
  # if total_batch < len(y)/batch_size:
  #   total_batch += 1
  data = data_generator(x1, x2, y, batch_size)
  for batch_ind in range(total_batch): 
    minibatch_x1, minibatch_x2, minibatch_y = next(data)
    train_step(minibatch_x1, minibatch_x2, minibatch_y)
    if batch_ind % 10 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f} AUC {:.4f}'.format(
          epoch + 1, batch_ind, train_loss.result(), train_accuracy.result(), train_AUC.result()))
      
  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,ckpt_save_path))
    
  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, train_loss.result(),train_accuracy.result()))
  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 0.3805 Accuracy 0.2500 AUC 0.6780
# Epoch 1 Batch 10 Loss 0.1529 Accuracy 0.7770 AUC 0.4993
# Epoch 1 Batch 20 Loss 0.0986 Accuracy 0.8296 AUC 0.4826
# Epoch 1 Batch 30 Loss 0.0790 Accuracy 0.8483 AUC 0.5048
# Epoch 1 Batch 40 Loss 0.0712 Accuracy 0.8537 AUC 0.5133
# Epoch 1 Batch 50 Loss 0.0695 Accuracy 0.8523 AUC 0.5079
# Epoch 1 Batch 60 Loss 0.0647 Accuracy 0.8581 AUC 0.5045
# Epoch 1 Batch 70 Loss 0.0614 Accuracy 0.8607 AUC 0.5062
# Epoch 1 Batch 80 Loss 0.0584 Accuracy 0.8652 AUC 0.5082
# Epoch 1 Batch 90 Loss 0.0563 Accuracy 0.8681 AUC 0.5080
# Epoch 1 Batch 100 Loss 0.0554 Accuracy 0.8691 AUC 0.5077
# Epoch 1 Batch 110 Loss 0.0547 Accuracy 0.8680 AUC 0.5073
# Epoch 1 Batch 120 Loss 0.0535 Accuracy 0.8691 AUC 0.5046
# Epoch 1 Batch 130 Loss 0.0529 Accuracy 0.8678 AUC 0.5082
# Epoch 1 Batch 140 Loss 0.0517 Accuracy 0.8693 AUC 0.5079
# Epoch 1 Batch 150 Loss 0.0509 Accuracy 0.8691 AUC 0.5095
# Epoch 1 Batch 160 Loss 0.0500 Accuracy 0.8701 AUC 0.5103
# Epoch 1 Batch 170 Loss 0.0492 Accuracy 0.8706 AUC 0.5137
# Epoch 1 Batch 180 Loss 0.0489 Accuracy 0.8705 AUC 0.5127
# Epoch 1 Batch 190 Loss 0.0488 Accuracy 0.8698 AUC 0.5134
# Epoch 1 Batch 200 Loss 0.0483 Accuracy 0.8704 AUC 0.5100
# Epoch 1 Batch 210 Loss 0.0481 Accuracy 0.8701 AUC 0.5099
# Epoch 1 Batch 220 Loss 0.0476 Accuracy 0.8710 AUC 0.5093
# Epoch 1 Batch 230 Loss 0.0473 Accuracy 0.8704 AUC 0.5129
# Epoch 1 Batch 240 Loss 0.0473 Accuracy 0.8696 AUC 0.5132
# Epoch 1 Batch 250 Loss 0.0471 Accuracy 0.8695 AUC 0.5115
# Epoch 1 Batch 260 Loss 0.0468 Accuracy 0.8697 AUC 0.5118
# Epoch 1 Batch 270 Loss 0.0465 Accuracy 0.8702 AUC 0.5113
# Epoch 1 Loss 0.0465 Accuracy 0.8694
# Time taken for 1 epoch: 101.34027981758118 secs
#
# Epoch 2 Batch 0 Loss 0.0283 Accuracy 0.9219 AUC 0.4627
# Epoch 2 Batch 10 Loss 0.0416 Accuracy 0.8636 AUC 0.5142
# Epoch 2 Batch 20 Loss 0.0393 Accuracy 0.8757 AUC 0.4934
# Epoch 2 Batch 30 Loss 0.0383 Accuracy 0.8795 AUC 0.5062
# Epoch 2 Batch 40 Loss 0.0394 Accuracy 0.8777 AUC 0.4948
# Epoch 2 Batch 50 Loss 0.0400 Accuracy 0.8735 AUC 0.5059
# Epoch 2 Batch 60 Loss 0.0398 Accuracy 0.8758 AUC 0.5141
# Epoch 2 Batch 70 Loss 0.0399 Accuracy 0.8759 AUC 0.5177
# Epoch 2 Batch 80 Loss 0.0398 Accuracy 0.8787 AUC 0.5168
# Epoch 2 Batch 90 Loss 0.0394 Accuracy 0.8802 AUC 0.5168
# Epoch 2 Batch 100 Loss 0.0394 Accuracy 0.8800 AUC 0.5125
# Epoch 2 Batch 110 Loss 0.0396 Accuracy 0.8778 AUC 0.5160
# Epoch 2 Batch 120 Loss 0.0394 Accuracy 0.8781 AUC 0.5135
# Epoch 2 Batch 130 Loss 0.0395 Accuracy 0.8762 AUC 0.5179
# Epoch 2 Batch 140 Loss 0.0392 Accuracy 0.8771 AUC 0.5159
# Epoch 2 Batch 150 Loss 0.0393 Accuracy 0.8763 AUC 0.5159
# Epoch 2 Batch 160 Loss 0.0391 Accuracy 0.8768 AUC 0.5160
# Epoch 2 Batch 170 Loss 0.0390 Accuracy 0.8770 AUC 0.5156
# Epoch 2 Batch 180 Loss 0.0390 Accuracy 0.8766 AUC 0.5164
# Epoch 2 Batch 190 Loss 0.0393 Accuracy 0.8755 AUC 0.5162
# Epoch 2 Batch 200 Loss 0.0391 Accuracy 0.8759 AUC 0.5173
# Epoch 2 Batch 210 Loss 0.0392 Accuracy 0.8754 AUC 0.5169
# Epoch 2 Batch 220 Loss 0.0391 Accuracy 0.8760 AUC 0.5155
# Epoch 2 Batch 230 Loss 0.0392 Accuracy 0.8753 AUC 0.5144
# Epoch 2 Batch 240 Loss 0.0394 Accuracy 0.8743 AUC 0.5133
# Epoch 2 Batch 250 Loss 0.0395 Accuracy 0.8740 AUC 0.5131
# Epoch 2 Batch 260 Loss 0.0395 Accuracy 0.8740 AUC 0.5117
# Epoch 2 Batch 270 Loss 0.0394 Accuracy 0.8744 AUC 0.5117
# Epoch 2 Loss 0.0395 Accuracy 0.8735
# Time taken for 1 epoch: 96.63481831550598 secs
#
# Epoch 3 Batch 0 Loss 0.0338 Accuracy 0.9219 AUC 0.4508
# Epoch 3 Batch 10 Loss 0.0408 Accuracy 0.8636 AUC 0.4786
# Epoch 3 Batch 20 Loss 0.0385 Accuracy 0.8757 AUC 0.4834
# Epoch 3 Batch 30 Loss 0.0379 Accuracy 0.8795 AUC 0.4660
# Epoch 3 Batch 40 Loss 0.0378 Accuracy 0.8777 AUC 0.4949
# Epoch 3 Batch 50 Loss 0.0391 Accuracy 0.8735 AUC 0.4864
# Epoch 3 Batch 60 Loss 0.0388 Accuracy 0.8758 AUC 0.4869
# Epoch 3 Batch 70 Loss 0.0390 Accuracy 0.8759 AUC 0.4793
# Epoch 3 Batch 80 Loss 0.0383 Accuracy 0.8787 AUC 0.4775
# Epoch 3 Batch 90 Loss 0.0380 Accuracy 0.8802 AUC 0.4728
# Epoch 3 Batch 100 Loss 0.0379 Accuracy 0.8800 AUC 0.4740
# Epoch 3 Batch 110 Loss 0.0381 Accuracy 0.8778 AUC 0.4848
# Epoch 3 Batch 120 Loss 0.0379 Accuracy 0.8781 AUC 0.4878
# Epoch 3 Batch 130 Loss 0.0382 Accuracy 0.8762 AUC 0.4960
# Epoch 3 Batch 140 Loss 0.0380 Accuracy 0.8771 AUC 0.4963
# Epoch 3 Batch 150 Loss 0.0380 Accuracy 0.8763 AUC 0.4990
# Epoch 3 Batch 160 Loss 0.0378 Accuracy 0.8768 AUC 0.5040
# Epoch 3 Batch 170 Loss 0.0378 Accuracy 0.8770 AUC 0.5015
# Epoch 3 Batch 180 Loss 0.0378 Accuracy 0.8766 AUC 0.5028
# Epoch 3 Batch 190 Loss 0.0380 Accuracy 0.8755 AUC 0.5053
# Epoch 3 Batch 200 Loss 0.0379 Accuracy 0.8759 AUC 0.5051
# Epoch 3 Batch 210 Loss 0.0379 Accuracy 0.8754 AUC 0.5064
# Epoch 3 Batch 220 Loss 0.0378 Accuracy 0.8760 AUC 0.5080
# Epoch 3 Batch 230 Loss 0.0378 Accuracy 0.8753 AUC 0.5108
# Epoch 3 Batch 240 Loss 0.0380 Accuracy 0.8743 AUC 0.5094
# Epoch 3 Batch 250 Loss 0.0381 Accuracy 0.8740 AUC 0.5089
# Epoch 3 Batch 260 Loss 0.0381 Accuracy 0.8740 AUC 0.5082
# Epoch 3 Batch 270 Loss 0.0380 Accuracy 0.8744 AUC 0.5085
# Epoch 3 Loss 0.0382 Accuracy 0.8735
# Time taken for 1 epoch: 95.87811875343323 secs
#
# Epoch 4 Batch 0 Loss 0.0339 Accuracy 0.9219 AUC 0.4407
# Epoch 4 Batch 10 Loss 0.0400 Accuracy 0.8636 AUC 0.5123
# Epoch 4 Batch 20 Loss 0.0374 Accuracy 0.8757 AUC 0.5090
# Epoch 4 Batch 30 Loss 0.0367 Accuracy 0.8795 AUC 0.5008
# Epoch 4 Batch 40 Loss 0.0369 Accuracy 0.8777 AUC 0.5206
# Epoch 4 Batch 50 Loss 0.0377 Accuracy 0.8735 AUC 0.5276
# Epoch 4 Batch 60 Loss 0.0375 Accuracy 0.8758 AUC 0.5215
# Epoch 4 Batch 70 Loss 0.0375 Accuracy 0.8759 AUC 0.5162
# Epoch 4 Batch 80 Loss 0.0369 Accuracy 0.8787 AUC 0.5195
# Epoch 4 Batch 90 Loss 0.0365 Accuracy 0.8802 AUC 0.5170
# Epoch 4 Batch 100 Loss 0.0365 Accuracy 0.8800 AUC 0.5181
# Epoch 4 Batch 110 Loss 0.0367 Accuracy 0.8778 AUC 0.5276
# Epoch 4 Batch 120 Loss 0.0366 Accuracy 0.8781 AUC 0.5300
# Epoch 4 Batch 130 Loss 0.0369 Accuracy 0.8762 AUC 0.5365
# Epoch 4 Batch 140 Loss 0.0367 Accuracy 0.8771 AUC 0.5402
# Epoch 4 Batch 150 Loss 0.0368 Accuracy 0.8763 AUC 0.5419
# Epoch 4 Batch 160 Loss 0.0366 Accuracy 0.8768 AUC 0.5429
# Epoch 4 Batch 170 Loss 0.0365 Accuracy 0.8770 AUC 0.5446
# Epoch 4 Batch 180 Loss 0.0367 Accuracy 0.8766 AUC 0.5425
# Epoch 4 Batch 190 Loss 0.0369 Accuracy 0.8755 AUC 0.5449
# Epoch 4 Batch 200 Loss 0.0368 Accuracy 0.8759 AUC 0.5434
# Epoch 4 Batch 210 Loss 0.0369 Accuracy 0.8754 AUC 0.5452
# Epoch 4 Batch 220 Loss 0.0367 Accuracy 0.8760 AUC 0.5474
# Epoch 4 Batch 230 Loss 0.0369 Accuracy 0.8753 AUC 0.5471
# Epoch 4 Batch 240 Loss 0.0371 Accuracy 0.8743 AUC 0.5469
# Epoch 4 Batch 250 Loss 0.0371 Accuracy 0.8740 AUC 0.5459
# Epoch 4 Batch 260 Loss 0.0372 Accuracy 0.8740 AUC 0.5430
# Epoch 4 Batch 270 Loss 0.0371 Accuracy 0.8744 AUC 0.5422
# Epoch 4 Loss 0.0373 Accuracy 0.8735
# Time taken for 1 epoch: 98.80717825889587 secs
#
# Epoch 5 Batch 0 Loss 0.0301 Accuracy 0.9219 AUC 0.7254
# Epoch 5 Batch 10 Loss 0.0395 Accuracy 0.8636 AUC 0.5166
# Epoch 5 Batch 20 Loss 0.0372 Accuracy 0.8757 AUC 0.5115
# Epoch 5 Batch 30 Loss 0.0364 Accuracy 0.8795 AUC 0.5032
# Epoch 5 Batch 40 Loss 0.0367 Accuracy 0.8777 AUC 0.5146
# Epoch 5 Batch 50 Loss 0.0375 Accuracy 0.8735 AUC 0.5216
# Epoch 5 Batch 60 Loss 0.0373 Accuracy 0.8758 AUC 0.5165
# Epoch 5 Batch 70 Loss 0.0372 Accuracy 0.8759 AUC 0.5160
# Epoch 5 Batch 80 Loss 0.0366 Accuracy 0.8787 AUC 0.5180
# Epoch 5 Batch 90 Loss 0.0363 Accuracy 0.8802 AUC 0.5190
# Epoch 5 Batch 100 Loss 0.0362 Accuracy 0.8800 AUC 0.5236
# Epoch 5 Batch 110 Loss 0.0366 Accuracy 0.8778 AUC 0.5284
# Epoch 5 Batch 120 Loss 0.0364 Accuracy 0.8781 AUC 0.5315
# Epoch 5 Batch 130 Loss 0.0367 Accuracy 0.8762 AUC 0.5404
# Epoch 5 Batch 140 Loss 0.0365 Accuracy 0.8771 AUC 0.5390
# Epoch 5 Batch 150 Loss 0.0366 Accuracy 0.8763 AUC 0.5430
# Epoch 5 Batch 160 Loss 0.0364 Accuracy 0.8768 AUC 0.5428
# Epoch 5 Batch 170 Loss 0.0364 Accuracy 0.8770 AUC 0.5432
# Epoch 5 Batch 180 Loss 0.0365 Accuracy 0.8766 AUC 0.5427
# Epoch 5 Batch 190 Loss 0.0367 Accuracy 0.8755 AUC 0.5429
# Epoch 5 Batch 200 Loss 0.0366 Accuracy 0.8759 AUC 0.5432
# Epoch 5 Batch 210 Loss 0.0367 Accuracy 0.8754 AUC 0.5442
# Epoch 5 Batch 220 Loss 0.0365 Accuracy 0.8760 AUC 0.5468
# Epoch 5 Batch 230 Loss 0.0367 Accuracy 0.8753 AUC 0.5464
# Epoch 5 Batch 240 Loss 0.0369 Accuracy 0.8743 AUC 0.5446
# Epoch 5 Batch 250 Loss 0.0370 Accuracy 0.8740 AUC 0.5429
# Epoch 5 Batch 260 Loss 0.0370 Accuracy 0.8740 AUC 0.5406
# Epoch 5 Batch 270 Loss 0.0369 Accuracy 0.8744 AUC 0.5408
# Saving checkpoint for epoch 5 at checkpoints/train/ckpt-1
# Epoch 5 Loss 0.0371 Accuracy 0.8735
# Time taken for 1 epoch: 95.3511254787445 secs
#
# Epoch 6 Batch 0 Loss 0.0323 Accuracy 0.9219 AUC 0.6695
# Epoch 6 Batch 10 Loss 0.0394 Accuracy 0.8636 AUC 0.5353
# Epoch 6 Batch 20 Loss 0.0370 Accuracy 0.8757 AUC 0.5257
# Epoch 6 Batch 30 Loss 0.0362 Accuracy 0.8795 AUC 0.5253
# Epoch 6 Batch 40 Loss 0.0362 Accuracy 0.8777 AUC 0.5425
# Epoch 6 Batch 50 Loss 0.0372 Accuracy 0.8735 AUC 0.5340
# Epoch 6 Batch 60 Loss 0.0369 Accuracy 0.8758 AUC 0.5338
# Epoch 6 Batch 70 Loss 0.0369 Accuracy 0.8759 AUC 0.5286
# Epoch 6 Batch 80 Loss 0.0364 Accuracy 0.8787 AUC 0.5273
# Epoch 6 Batch 90 Loss 0.0360 Accuracy 0.8802 AUC 0.5269
# Epoch 6 Batch 100 Loss 0.0360 Accuracy 0.8800 AUC 0.5334
# Epoch 6 Batch 110 Loss 0.0362 Accuracy 0.8778 AUC 0.5440
# Epoch 6 Batch 120 Loss 0.0361 Accuracy 0.8781 AUC 0.5465
# Epoch 6 Batch 130 Loss 0.0364 Accuracy 0.8762 AUC 0.5518
# Epoch 6 Batch 140 Loss 0.0362 Accuracy 0.8771 AUC 0.5532
# Epoch 6 Batch 150 Loss 0.0363 Accuracy 0.8763 AUC 0.5568
# Epoch 6 Batch 160 Loss 0.0362 Accuracy 0.8768 AUC 0.5541
# Epoch 6 Batch 170 Loss 0.0362 Accuracy 0.8770 AUC 0.5532
# Epoch 6 Batch 180 Loss 0.0363 Accuracy 0.8766 AUC 0.5516
# Epoch 6 Batch 190 Loss 0.0365 Accuracy 0.8755 AUC 0.5545
# Epoch 6 Batch 200 Loss 0.0364 Accuracy 0.8759 AUC 0.5545
# Epoch 6 Batch 210 Loss 0.0365 Accuracy 0.8754 AUC 0.5542
# Epoch 6 Batch 220 Loss 0.0364 Accuracy 0.8760 AUC 0.5551
# Epoch 6 Batch 230 Loss 0.0366 Accuracy 0.8753 AUC 0.5525
# Epoch 6 Batch 240 Loss 0.0368 Accuracy 0.8743 AUC 0.5532
# Epoch 6 Batch 250 Loss 0.0368 Accuracy 0.8740 AUC 0.5521
# Epoch 6 Batch 260 Loss 0.0368 Accuracy 0.8740 AUC 0.5507
# Epoch 6 Batch 270 Loss 0.0368 Accuracy 0.8744 AUC 0.5510
# Epoch 6 Loss 0.0369 Accuracy 0.8735
# Time taken for 1 epoch: 95.49437379837036 secs
#
# Epoch 7 Batch 0 Loss 0.0341 Accuracy 0.9219 AUC 0.4864
# Epoch 7 Batch 10 Loss 0.0395 Accuracy 0.8636 AUC 0.5077
# Epoch 7 Batch 20 Loss 0.0367 Accuracy 0.8757 AUC 0.5209
# Epoch 7 Batch 30 Loss 0.0360 Accuracy 0.8795 AUC 0.5293
# Epoch 7 Batch 40 Loss 0.0362 Accuracy 0.8777 AUC 0.5483
# Epoch 7 Batch 50 Loss 0.0372 Accuracy 0.8735 AUC 0.5425
# Epoch 7 Batch 60 Loss 0.0368 Accuracy 0.8758 AUC 0.5412
# Epoch 7 Batch 70 Loss 0.0370 Accuracy 0.8759 AUC 0.5310
# Epoch 7 Batch 80 Loss 0.0365 Accuracy 0.8787 AUC 0.5289
# Epoch 7 Batch 90 Loss 0.0361 Accuracy 0.8802 AUC 0.5280
# Epoch 7 Batch 100 Loss 0.0360 Accuracy 0.8800 AUC 0.5345
# Epoch 7 Batch 110 Loss 0.0363 Accuracy 0.8778 AUC 0.5424
# Epoch 7 Batch 120 Loss 0.0362 Accuracy 0.8781 AUC 0.5451
# Epoch 7 Batch 130 Loss 0.0364 Accuracy 0.8762 AUC 0.5524
# Epoch 7 Batch 140 Loss 0.0363 Accuracy 0.8771 AUC 0.5496
# Epoch 7 Batch 150 Loss 0.0364 Accuracy 0.8763 AUC 0.5527
# Epoch 7 Batch 160 Loss 0.0363 Accuracy 0.8768 AUC 0.5518
# Epoch 7 Batch 170 Loss 0.0362 Accuracy 0.8770 AUC 0.5514
# Epoch 7 Batch 180 Loss 0.0363 Accuracy 0.8766 AUC 0.5502
# Epoch 7 Batch 190 Loss 0.0365 Accuracy 0.8755 AUC 0.5538
# Epoch 7 Batch 200 Loss 0.0364 Accuracy 0.8759 AUC 0.5549
# Epoch 7 Batch 210 Loss 0.0365 Accuracy 0.8754 AUC 0.5565
# Epoch 7 Batch 220 Loss 0.0364 Accuracy 0.8760 AUC 0.5582
# Epoch 7 Batch 230 Loss 0.0365 Accuracy 0.8753 AUC 0.5595
# Epoch 7 Batch 240 Loss 0.0367 Accuracy 0.8743 AUC 0.5579
# Epoch 7 Batch 250 Loss 0.0368 Accuracy 0.8740 AUC 0.5556
# Epoch 7 Batch 260 Loss 0.0367 Accuracy 0.8740 AUC 0.5547
# Epoch 7 Batch 270 Loss 0.0367 Accuracy 0.8744 AUC 0.5563
# Epoch 7 Loss 0.0368 Accuracy 0.8735
# Time taken for 1 epoch: 95.28544807434082 secs
#
# Epoch 8 Batch 0 Loss 0.0342 Accuracy 0.9219 AUC 0.5610
# Epoch 8 Batch 10 Loss 0.0397 Accuracy 0.8636 AUC 0.5160
# Epoch 8 Batch 20 Loss 0.0368 Accuracy 0.8757 AUC 0.5375
# Epoch 8 Batch 30 Loss 0.0360 Accuracy 0.8795 AUC 0.5329
# Epoch 8 Batch 40 Loss 0.0363 Accuracy 0.8777 AUC 0.5391
# Epoch 8 Batch 50 Loss 0.0371 Accuracy 0.8735 AUC 0.5409
# Epoch 8 Batch 60 Loss 0.0369 Accuracy 0.8758 AUC 0.5378
# Epoch 8 Batch 70 Loss 0.0370 Accuracy 0.8759 AUC 0.5357
# Epoch 8 Batch 80 Loss 0.0364 Accuracy 0.8787 AUC 0.5344
# Epoch 8 Batch 90 Loss 0.0361 Accuracy 0.8802 AUC 0.5315
# Epoch 8 Batch 100 Loss 0.0360 Accuracy 0.8800 AUC 0.5342
# Epoch 8 Batch 110 Loss 0.0362 Accuracy 0.8778 AUC 0.5462
# Epoch 8 Batch 120 Loss 0.0361 Accuracy 0.8781 AUC 0.5502
# Epoch 8 Batch 130 Loss 0.0364 Accuracy 0.8762 AUC 0.5591
# Epoch 8 Batch 140 Loss 0.0362 Accuracy 0.8771 AUC 0.5581
# Epoch 8 Batch 150 Loss 0.0363 Accuracy 0.8763 AUC 0.5603
# Epoch 8 Batch 160 Loss 0.0361 Accuracy 0.8768 AUC 0.5603
# Epoch 8 Batch 170 Loss 0.0361 Accuracy 0.8770 AUC 0.5624
# Epoch 8 Batch 180 Loss 0.0362 Accuracy 0.8766 AUC 0.5634
# Epoch 8 Batch 190 Loss 0.0364 Accuracy 0.8755 AUC 0.5651
# Epoch 8 Batch 200 Loss 0.0363 Accuracy 0.8759 AUC 0.5645
# Epoch 8 Batch 210 Loss 0.0363 Accuracy 0.8754 AUC 0.5668
# Epoch 8 Batch 220 Loss 0.0362 Accuracy 0.8760 AUC 0.5687
# Epoch 8 Batch 230 Loss 0.0363 Accuracy 0.8753 AUC 0.5695
# Epoch 8 Batch 240 Loss 0.0365 Accuracy 0.8743 AUC 0.5688
# Epoch 8 Batch 250 Loss 0.0366 Accuracy 0.8740 AUC 0.5683
# Epoch 8 Batch 260 Loss 0.0366 Accuracy 0.8740 AUC 0.5677
# Epoch 8 Batch 270 Loss 0.0365 Accuracy 0.8744 AUC 0.5677
# Epoch 8 Loss 0.0366 Accuracy 0.8735
# Time taken for 1 epoch: 95.03872013092041 secs

# %% [markdown]
# # Evaluate

# %%
test_predictions, _ = sample_transformer(test_behavior, test_stay_time, True, len(test_label))

# %%
train_AUC.reset_states()
train_AUC.update_state(test_label,test_predictions)
auc = train_AUC.result().numpy()
print("AUC result:", auc)
# Out:
# AUC result: 0.59931487

# %%
train_accuracy.update_state(test_label,test_predictions)
accuracy = train_accuracy.result().numpy()
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8724057

# %%
fpr, tpr, threshold = roc_curve(test_label, test_predictions)
ks = (tpr-fpr)
max_ = np.argmax(ks)
print("KS:", ks)

# %%
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
